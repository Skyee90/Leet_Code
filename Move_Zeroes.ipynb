# %% [markdown]
# 283. Move Zeroes
#
# Given an integer array nums, move all 0's to the end of it while maintaining the relative order of the non-zero elements.
#
# Note :- that you must do this in-place without making a copy of the array.
#
#
#
# Example 1:
#
# Input: nums = [0,1,0,3,12]
# Output: [1,3,12,0,0]

# %% [markdown]
# """
# LeetCode 283 — Move Zeroes
# Topic: Two Pointers (In-place array manipulation)
# Difficulty: Easy
#
# Approach:
# Use two pointers. The 'right' pointer scans the array, and the 'left' pointer
# tracks where the next non-zero element should go. When a non-zero element is found,
# swap it with the element at 'left' and move 'left' forward. This keeps all non-zero
# elements in order and moves zeros to the end.
#
# Time Complexity: O(n)
# Space Complexity: O(1)
# """

# %%
class Solution:
    def moveZeroes(self, nums: List[int]) -> None:
        left = 0

        for right in range(len(nums)):
            if nums[right] != 0:
                nums[right], nums[left] = nums[left], nums[right]
                left += 1
        return nums
